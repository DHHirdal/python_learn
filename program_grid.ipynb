# %% [markdown]
# <a href="https://colab.research.google.com/github/DHHirdal/python_learn/blob/main/program_grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mt
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,3,10,5,1])
ypoints = np.array([4,8,2,8,0,5])

plt.plot(xpoints, ls='dashed', color ='g')
plt.plot(ypoints, ls='-.', color ='m')
fontdict1 ={'family':'serif', 'color':'r','size':15 }
fontdict2 ={'family':'serif', 'color':'b','size':20 }
plt.title("time-Distance graph", loc='right')
plt.xlabel ("distance", fontdict=fontdict1)
plt.ylabel("time",fontdict=fontdict2)
plt.grid()

# %% [markdown]
# Add grid ony to x-axis

# %%
import matplotlib as mt
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,3,10,5,1])
ypoints = np.array([4,8,2,8,0,5])

plt.plot(xpoints, ls='dashed', color ='g')
plt.plot(ypoints, ls='-.', color ='m')
fontdict1 ={'family':'serif', 'color':'r','size':15 }
fontdict2 ={'family':'serif', 'color':'b','size':20 }
plt.title("time-Distance graph", loc='right')
plt.xlabel ("distance", fontdict=fontdict1)
plt.ylabel("time",fontdict=fontdict2)
plt.grid(axis='x') # this is the specifier

# %% [markdown]
# this is add grid to y-axis only

# %%
import matplotlib as mt
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,3,10,5,1])
ypoints = np.array([4,8,2,8,0,5])

plt.plot(xpoints, ls='dashed', color ='g')
plt.plot(ypoints, ls='-.', color ='m')
fontdict1 ={'family':'serif', 'color':'r','size':15 }
fontdict2 ={'family':'serif', 'color':'b','size':20 }
plt.title("time-Distance graph", loc='right')
plt.xlabel ("distance", fontdict=fontdict1)
plt.ylabel("time",fontdict=fontdict2)
plt.grid(axis='y') # this is the specifier

# %%
import matplotlib as mt
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,3,10,5,1])
ypoints = np.array([4,8,2,8,0,5])

plt.plot(xpoints, ls='dashed', color ='g')
plt.plot(ypoints, ls='-.', color ='m')
fontdict1 ={'family':'serif', 'color':'r','size':15 }
fontdict2 ={'family':'serif', 'color':'b','size':20 }
plt.title("time-Distance graph", loc='left') # title moved to left
plt.xlabel ("distance", fontdict=fontdict1)
plt.ylabel("time",fontdict=fontdict2)
plt.grid(color ='c', linestyle ='-.', linewidth = 1) #line style is changed (added format)
